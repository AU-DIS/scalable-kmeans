# %%
###Drawing number of features used in distance calculation in respect to DCT components used

from curses import A_ALTCHARSET
import matplotlib.pyplot as plt
from operator import truediv

fig_sizex = 8
fig_sizey = 8

###Calculation count comparison
LlKmeans = [23520, 94080, 376320, 1505280, 4300800, 18923520, 72253440, 330301440, 1541406720]
ElKmeans = [9656, 38428, 154480, 617344, 1835264, 8040448, 31035392, 143392768, 659423232]
HamKmeans = [19164, 77200, 310048, 1244224, 3587328, 15918080, 62337024, 292225024, 1386283008]
ElNewTE = [9656, 38428, 154480, 617344, 1835264, 8040448, 31035392, 143392768, 659423232]
HamNewTE = [6599, 74844, 300384, 1203584, 3438080, 15230976, 58978304, 268828672, 1235025920]
ElHamNewTE = [9765, 38888, 155744, 644032, 1855744, 8114176, 31281152, 144277504, 662896640]
StepKmeans = [23520, 76800, 376320, 1274304, 2876496, 10812912, 22406160, 81056832, 358480416]
MARIGOLD = [21406, 68831, 343440, 1122080, 2408640, 8933744, 21958896, 80692080, 357592320]
x_axis = [1, 2, 4, 8, 16, 32, 64, 128, 256]
iteration_value = [28, 28, 28, 28, 20, 22, 21, 24, 28]

LlKmeans = [x / y for x,y in zip(LlKmeans, iteration_value)]
ElKmeans = [x / y for x,y in zip(ElKmeans, iteration_value)]
HamKmeans = [x / y for x,y in zip(HamKmeans, iteration_value)]
ElNewTE = [x / y for x,y in zip(ElNewTE, iteration_value)]
HamNewTE = [x / y for x,y in zip(HamNewTE, iteration_value)]
ElHamNewTE = [x / y for x,y in zip(ElHamNewTE, iteration_value)]
StepKmeans = [x / y for x,y in zip(StepKmeans, iteration_value)]
MARIGOLD = [x / y for x,y in zip(MARIGOLD, iteration_value)]


myfig = plt.figure(figsize=(fig_sizex, fig_sizey))
#plt.subplot(2,1,1)
#plt.plot(x_axis, LlKmeans, color='blue', lw=1, label='LlKmeans')
plt.plot(x_axis, LlKmeans, lw=1, label='LlKmeans', linestyle=':', marker='v')
plt.plot(x_axis, ElKmeans, lw=1, label='ElKmeans', linestyle=':', marker='s')
plt.plot(x_axis, HamKmeans, lw=1, label='HamKmeans', linestyle=':', marker='h')
plt.plot(x_axis, ElNewTE, lw=1, label='ElNewTE', linestyle='-.', marker='d')
plt.plot(x_axis, HamNewTE, lw=1, label='HamNewTE', linestyle='-.', marker='+')
plt.plot(x_axis, ElHamNewTE, lw=1, label='ElHamNewTE', linestyle='-.', marker='x')
plt.plot(x_axis, StepKmeans, lw=1, label='StepKmeans', linestyle=':', marker='o')
plt.plot(x_axis, MARIGOLD, lw=1.5, label='MARIGOLD', linestyle='-.', marker='*')
#plt.yscale('log')
plt.xscale('log', base=2)
plt.ylabel('No. of features')
plt.xlabel('Value of n where no. of DCT components are (n x n)')
#plt.xlim(1, 7)
#plt.title('Comparing different methods in discarding number for feature points from distance calculation')
plt.title('Comparing feature numbers')
plt.legend(loc="upper left")
plt.xticks(x_axis)
plt.show()

image_format = 'svg' # e.g .png, .svg, etc.
image_name = 'img_feature numbers.svg'
myfig.savefig(image_name, format=image_format, dpi=600)

##############################################################################################


###Calculation count comparison
LlKmeans = [23520, 94080, 376320, 1505280, 4300800, 18923520, 72253440, 330301440, 1541406720]
ElKmeans = [9656, 38428, 154480, 617344, 1835264, 8040448, 31035392, 143392768, 659423232]
HamKmeans = [19164, 77200, 310048, 1244224, 3587328, 15918080, 62337024, 292225024, 1386283008]
ElNewTE = [9656, 38428, 154480, 617344, 1835264, 8040448, 31035392, 143392768, 659423232]
HamNewTE = [6599, 74844, 300384, 1203584, 3438080, 15230976, 58978304, 268828672, 1235025920]
ElHamNewTE = [9765, 38888, 155744, 644032, 1855744, 8114176, 31281152, 144277504, 662896640]
StepKmeans = [23520, 76800, 376320, 1274304, 2876496, 10812912, 22406160, 81056832, 358480416]
MARIGOLD = [21406, 68831, 343440, 1122080, 2408640, 8933744, 21958896, 80692080, 357592320]
x_axis = [1, 2, 4, 8, 16, 32, 64, 128, 256]
#x_axis = [1, 4, 16, 64, 256, 1024, 4096, 16384, 65536]
iteration_value = [28, 28, 28, 28, 20, 22, 21, 24, 28]

LlKmeans = [x / y for x,y in zip(LlKmeans, iteration_value)]
ElKmeans = [x / y for x,y in zip(ElKmeans, iteration_value)]
HamKmeans = [x / y for x,y in zip(HamKmeans, iteration_value)]
ElNewTE = [x / y for x,y in zip(ElNewTE, iteration_value)]
HamNewTE = [x / y for x,y in zip(HamNewTE, iteration_value)]
ElHamNewTE = [x / y for x,y in zip(ElHamNewTE, iteration_value)]
StepKmeans = [x / y for x,y in zip(StepKmeans, iteration_value)]
MARIGOLD = [x / y for x,y in zip(MARIGOLD, iteration_value)]


myfig = plt.figure(figsize=(fig_sizex, fig_sizey))
#plt.subplot(2,1,1)
#plt.plot(x_axis, LlKmeans, color='blue', lw=1, label='LlKmeans')
plt.plot(x_axis, LlKmeans, lw=1, label='LlKmeans', linestyle=':', marker='v')
plt.plot(x_axis, ElKmeans, lw=1, label='ElKmeans', linestyle=':', marker='s')
plt.plot(x_axis, HamKmeans, lw=1, label='HamKmeans', linestyle=':', marker='h')
plt.plot(x_axis, ElNewTE, lw=1, label='ElNewTE', linestyle='-.', marker='d')
plt.plot(x_axis, HamNewTE, lw=1, label='HamNewTE', linestyle='-.', marker='+')
plt.plot(x_axis, ElHamNewTE, lw=1, label='ElHamNewTE', linestyle='-.', marker='x')
plt.plot(x_axis, StepKmeans, lw=1, label='StepKmeans', linestyle=':', marker='o')
plt.plot(x_axis, MARIGOLD, lw=1.5, label='MARIGOLD', linestyle='-.', marker='*')
plt.yscale('log')
#plt.xscale('log', base=2)
plt.ylabel('No. of features (log-scaled)')
plt.xlabel('Value of n where no. of DCT components are (n x n)')
#plt.xlim(1, 7)
plt.title('Comparing feature numbers (log-scaled in y-axis)')
plt.legend(loc="upper left")
plt.xticks(x_axis)
plt.show()

image_format = 'svg' # e.g .png, .svg, etc.
image_name = 'img_feature numbers logy.svg'
myfig.savefig(image_name, format=image_format, dpi=600)

##############################################################################################



###Calculation count comparison
LlKmeans = [23520, 94080, 376320, 1505280, 4300800, 18923520, 72253440, 330301440, 1541406720]
ElKmeans = [9656, 38428, 154480, 617344, 1835264, 8040448, 31035392, 143392768, 659423232]
HamKmeans = [19164, 77200, 310048, 1244224, 3587328, 15918080, 62337024, 292225024, 1386283008]
ElNewTE = [9656, 38428, 154480, 617344, 1835264, 8040448, 31035392, 143392768, 659423232]
HamNewTE = [6599, 74844, 300384, 1203584, 3438080, 15230976, 58978304, 268828672, 1235025920]
ElHamNewTE = [9765, 38888, 155744, 644032, 1855744, 8114176, 31281152, 144277504, 662896640]
StepKmeans = [23520, 76800, 376320, 1274304, 2876496, 10812912, 22406160, 81056832, 358480416]
MARIGOLD = [21406, 68831, 343440, 1122080, 2408640, 8933744, 21958896, 80692080, 357592320]
x_axis = [1, 2, 4, 8, 16, 32, 64, 128, 256]
#x_axis = [1, 4, 16, 64, 256, 1024, 4096, 16384, 65536]
iteration_value = [28, 28, 28, 28, 20, 22, 21, 24, 28]

LlKmeans = [x / y for x,y in zip(LlKmeans, iteration_value)]
ElKmeans = [x / y for x,y in zip(ElKmeans, iteration_value)]
HamKmeans = [x / y for x,y in zip(HamKmeans, iteration_value)]
ElNewTE = [x / y for x,y in zip(ElNewTE, iteration_value)]
HamNewTE = [x / y for x,y in zip(HamNewTE, iteration_value)]
ElHamNewTE = [x / y for x,y in zip(ElHamNewTE, iteration_value)]
StepKmeans = [x / y for x,y in zip(StepKmeans, iteration_value)]
MARIGOLD = [x / y for x,y in zip(MARIGOLD, iteration_value)]


myfig = plt.figure(figsize=(fig_sizex, fig_sizey))
#plt.subplot(2,1,1)
#plt.plot(x_axis, LlKmeans, color='blue', lw=1, label='LlKmeans')
plt.plot(x_axis, LlKmeans, lw=1, label='LlKmeans', linestyle=':', marker='v')
plt.plot(x_axis, ElKmeans, lw=1, label='ElKmeans', linestyle=':', marker='s')
plt.plot(x_axis, HamKmeans, lw=1, label='HamKmeans', linestyle=':', marker='h')
plt.plot(x_axis, ElNewTE, lw=1, label='ElNewTE', linestyle='-.', marker='d')
plt.plot(x_axis, HamNewTE, lw=1, label='HamNewTE', linestyle='-.', marker='+')
plt.plot(x_axis, ElHamNewTE, lw=1, label='ElHamNewTE', linestyle='-.', marker='x')
plt.plot(x_axis, StepKmeans, lw=1, label='StepKmeans', linestyle=':', marker='o')
plt.plot(x_axis, MARIGOLD, lw=1.5, label='MARIGOLD', linestyle='-.', marker='*')
plt.yscale('log')
plt.xscale('log', base=2)
plt.ylabel('No. of features (log-scaled)')
plt.xlabel('Value of n where no. of DCT components are (n x n)')
#plt.xlim(1, 7)
plt.title('Comparing feature numbers (log-scaled in both axis)')
plt.legend(loc="upper left")
plt.xticks(x_axis)
plt.show()

image_format = 'svg' # e.g .png, .svg, etc.
image_name = 'img_feature numbers logx logy.svg'
myfig.savefig(image_name, format=image_format, dpi=600)

##############################################################################################






###Calculation count comparison
LlKmeans = [23520, 94080, 376320, 1505280, 4300800, 18923520, 72253440, 330301440, 1541406720]
ElKmeans = [9656, 38428, 154480, 617344, 1835264, 8040448, 31035392, 143392768, 659423232]
HamKmeans = [19164, 77200, 310048, 1244224, 3587328, 15918080, 62337024, 292225024, 1386283008]
ElNewTE = [9656, 38428, 154480, 617344, 1835264, 8040448, 31035392, 143392768, 659423232]
HamNewTE = [6599, 74844, 300384, 1203584, 3438080, 15230976, 58978304, 268828672, 1235025920]
ElHamNewTE = [9765, 38888, 155744, 644032, 1855744, 8114176, 31281152, 144277504, 662896640]
StepKmeans = [23520, 76800, 376320, 1274304, 2876496, 10812912, 22406160, 81056832, 358480416]
MARIGOLD = [21406, 68831, 343440, 1122080, 2408640, 8933744, 21958896, 80692080, 357592320]
x_axis = [1, 2, 4, 8, 16, 32, 64, 128, 256]
#x_axis = [1, 4, 16, 64, 256, 1024, 4096, 16384, 65536]
iteration_value = [28, 28, 28, 28, 20, 22, 21, 24, 28]

LlKmeans = [x / y for x,y in zip(LlKmeans, iteration_value)]
ElKmeans = [x / y for x,y in zip(ElKmeans, iteration_value)]
HamKmeans = [x / y for x,y in zip(HamKmeans, iteration_value)]
ElNewTE = [x / y for x,y in zip(ElNewTE, iteration_value)]
HamNewTE = [x / y for x,y in zip(HamNewTE, iteration_value)]
ElHamNewTE = [x / y for x,y in zip(ElHamNewTE, iteration_value)]
StepKmeans = [x / y for x,y in zip(StepKmeans, iteration_value)]
MARIGOLD = [x / y for x,y in zip(MARIGOLD, iteration_value)]


myfig = plt.figure(figsize=(fig_sizex, fig_sizey))
#plt.subplot(2,1,1)
#plt.plot(x_axis, LlKmeans, color='blue', lw=1, label='LlKmeans')
plt.plot(x_axis, StepKmeans, lw=1, label='StepKmeans', linestyle=':', marker='o')
plt.plot(x_axis, MARIGOLD, lw=1.5, label='MARIGOLD', linestyle='-.', marker='*')
plt.yscale('log')
plt.xscale('log', base=2)
plt.ylabel('No. of features (log-scaled)')
plt.xlabel('Value of n where no. of DCT components are (n x n)')
#plt.xlim(1, 7)
plt.title('Comparing feature numbers (only stepwise and MARIGOLD)')
plt.legend(loc="upper left")
plt.xticks(x_axis)
plt.show()

image_format = 'svg' # e.g .png, .svg, etc.
image_name = 'img_feature numbers step and MARIGOLD.svg'
myfig.savefig(image_name, format=image_format, dpi=600)

##############################################################################################






###Calculation count comparison in percentage
LlKmeans = [23520, 94080, 376320, 1505280, 4300800, 18923520, 72253440, 330301440, 1541406720]
ElKmeans = [9656, 38428, 154480, 617344, 1835264, 8040448, 31035392, 143392768, 659423232]
HamKmeans = [19164, 77200, 310048, 1244224, 3587328, 15918080, 62337024, 292225024, 1386283008]
ElNewTE = [9656, 38428, 154480, 617344, 1835264, 8040448, 31035392, 143392768, 659423232]
HamNewTE = [6599, 74844, 300384, 1203584, 3438080, 15230976, 58978304, 268828672, 1235025920]
ElHamNewTE = [9765, 38888, 155744, 644032, 1855744, 8114176, 31281152, 144277504, 662896640]
StepKmeans = [23520, 76800, 376320, 1274304, 2876496, 10812912, 22406160, 81056832, 358480416]
MARIGOLD = [21406, 68831, 343440, 1122080, 2408640, 8933744, 21958896, 80692080, 357592320]
x_axis = [1, 2, 4, 8, 16, 32, 64, 128, 256]
#x_axis = [1, 4, 16, 64, 256, 1024, 4096, 16384, 65536]
iteration_value = [28, 28, 28, 28, 20, 22, 21, 24, 28]

LlKmeans = [x / y for x,y in zip(LlKmeans, iteration_value)]
ElKmeans = [x / y for x,y in zip(ElKmeans, iteration_value)]
HamKmeans = [x / y for x,y in zip(HamKmeans, iteration_value)]
ElNewTE = [x / y for x,y in zip(ElNewTE, iteration_value)]
HamNewTE = [x / y for x,y in zip(HamNewTE, iteration_value)]
ElHamNewTE = [x / y for x,y in zip(ElHamNewTE, iteration_value)]
StepKmeans = [x / y for x,y in zip(StepKmeans, iteration_value)]
MARIGOLD = [x / y for x,y in zip(MARIGOLD, iteration_value)]




myfig = plt.figure(figsize=(fig_sizex, fig_sizey))
#plt.subplot(2,1,1)
#plt.plot(x_axis, LlKmeans, color='blue', lw=1, label='LlKmeans')
plt.plot(x_axis, LlKmeans, lw=1, label='LlKmeans', linestyle=':', marker='v')
plt.plot(x_axis, ElKmeans, lw=1, label='ElKmeans', linestyle=':', marker='s')
plt.plot(x_axis, HamKmeans, lw=1, label='HamKmeans', linestyle=':', marker='h')
plt.plot(x_axis, ElNewTE, lw=1, label='ElNewTE', linestyle='-.', marker='d')
plt.plot(x_axis, HamNewTE, lw=1, label='HamNewTE', linestyle='-.', marker='+')
plt.plot(x_axis, ElHamNewTE, lw=1, label='ElHamNewTE', linestyle='-.', marker='x')
plt.plot(x_axis, StepKmeans, lw=1, label='StepKmeans', linestyle=':', marker='o')
plt.plot(x_axis, MARIGOLD, lw=1.5, label='MARIGOLD', linestyle='-.', marker='*')
#plt.xscale('log')
plt.xscale('log', base=2)
plt.yscale('log')
plt.ylabel('No. of features (log-scaled)')
plt.xlabel('Value of n where no. of DCT components are (n x n)')
#plt.xlim(1, 7)
plt.title('Comparing feature numbers (Experimental play ground)')
plt.legend(loc="upper left")
plt.xticks(x_axis)
plt.show()

image_format = 'svg' # e.g .png, .svg, etc.
image_name = 'img_feature numbers (rough).svg'
myfig.savefig(image_name, format=image_format, dpi=600)

##############################################################################################

# %%
#### Missfit Bi5d With Optimizer

###Calculation count comparison in percentage
#LlKmeans = [23520, 94080, 376320, 1505280, 4300800, 18923520, 72253440, 330301440, 1541406720]
ElKmeans = [0.001, 0.004, 0.025, 0.110, 0.385, 1.778, 10.765]
HamKmeans = [0.005, 0.021, 0.081, 0.341, 1.107, 5.889, 34.423]
#ElNewTE = [9656, 38428, 154480, 617344, 1835264, 8040448, 31035392, 143392768, 659423232]
#HamNewTE = [6599, 74844, 300384, 1203584, 3438080, 15230976, 58978304, 268828672, 1235025920]
#ElHamNewTE = [9765, 38888, 155744, 644032, 1855744, 8114176, 31281152, 144277504, 662896640]
StepKmeans = [0.004, 0.005, 0.015, 0.071, 0.214, 0.928, 4.612]
#MARIGOLD = [21406, 68831, 343440, 1122080, 2408640, 8933744, 21958896, 80692080, 357592320]
x_axis = [16*16, 32*32, 64*64, 128*128, 256*256, 512*512, 1024*1024]
#x_axis = [1, 4, 16, 64, 256, 1024, 4096, 16384, 65536]
#iteration_value = [28, 28, 28, 28, 20, 22, 21, 24, 28]

#LlKmeans = [x / y for x,y in zip(LlKmeans, iteration_value)]
#ElKmeans = [x / y for x,y in zip(ElKmeans, iteration_value)]
#HamKmeans = [x / y for x,y in zip(HamKmeans, iteration_value)]
#ElNewTE = [x / y for x,y in zip(ElNewTE, iteration_value)]
#HamNewTE = [x / y for x,y in zip(HamNewTE, iteration_value)]
#ElHamNewTE = [x / y for x,y in zip(ElHamNewTE, iteration_value)]
#StepKmeans = [x / y for x,y in zip(StepKmeans, iteration_value)]
#MARIGOLD = [x / y for x,y in zip(MARIGOLD, iteration_value)]




myfig = plt.figure(figsize=(fig_sizex, fig_sizey))
#plt.subplot(2,1,1)
#plt.plot(x_axis, LlKmeans, color='blue', lw=1, label='LlKmeans')
#plt.plot(x_axis, LlKmeans, lw=1, label='LlKmeans', linestyle=':', marker='v')
plt.plot(x_axis, ElKmeans, lw=1, label='ElKmeans', linestyle=':', marker='s')
plt.plot(x_axis, HamKmeans, lw=1, label='HamKmeans', linestyle=':', marker='h')
#plt.plot(x_axis, ElNewTE, lw=1, label='ElNewTE', linestyle='-.', marker='d')
#plt.plot(x_axis, HamNewTE, lw=1, label='HamNewTE', linestyle='-.', marker='+')
#plt.plot(x_axis, ElHamNewTE, lw=1, label='ElHamNewTE', linestyle='-.', marker='x')
plt.plot(x_axis, StepKmeans, lw=1, label='StepKmeans', linestyle=':', marker='o')
#plt.plot(x_axis, MARIGOLD, lw=1.5, label='MARIGOLD', linestyle='-.', marker='*')
#plt.xscale('log')
plt.xscale('log', base=2)
plt.yscale('log')
plt.ylabel('Runtime (s)')
plt.xlabel('DCT components')
#plt.xlim(1, 7)
plt.title('Missfit Bi5d N:168 K:5 Compiler:Clang Optimizer:O2')
plt.legend(loc="upper left")
plt.xticks(x_axis)
plt.show()

image_format = 'svg' # e.g .png, .svg, etc.
image_name = 'img_feature numbers (rough).svg'
myfig.savefig(image_name, format=image_format, dpi=600)

##############################################################################################

# %%
#### Missfit Bi5d Without Optimizer

###Calculation count comparison in percentage
#LlKmeans = [23520, 94080, 376320, 1505280, 4300800, 18923520, 72253440, 330301440, 1541406720]
ElKmeans   = [0.003 ,0.01, 0.049, 0.15, 0.58, 2.04, 8.8, 30.16]
HamKmeans  = [0.006 ,0.03, 0.10, 0.33, 1.24, 3.76, 18.68, 69.44]
#ElNewTE = [9656, 38428, 154480, 617344, 1835264, 8040448, 31035392, 143392768, 659423232]
#HamNewTE = [6599, 74844, 300384, 1203584, 3438080, 15230976, 58978304, 268828672, 1235025920]
#ElHamNewTE = [9765, 38888, 155744, 644032, 1855744, 8114176, 31281152, 144277504, 662896640]
StepKmeans = [0.01, 0.02, 0.056, 0.13, 0.43, 1.81, 5.62, 20.27]
#MARIGOLD = [21406, 68831, 343440, 1122080, 2408640, 8933744, 21958896, 80692080, 357592320]
x_axis = [8*8 ,16*16, 32*32, 64*64, 128*128, 256*256, 512*512, 1024*1024]
#x_axis = [1, 4, 16, 64, 256, 1024, 4096, 16384, 65536]
#iteration_value = [28, 28, 28, 28, 20, 22, 21, 24, 28]

#LlKmeans = [x / y for x,y in zip(LlKmeans, iteration_value)]
#ElKmeans = [x / y for x,y in zip(ElKmeans, iteration_value)]
#HamKmeans = [x / y for x,y in zip(HamKmeans, iteration_value)]
#ElNewTE = [x / y for x,y in zip(ElNewTE, iteration_value)]
#HamNewTE = [x / y for x,y in zip(HamNewTE, iteration_value)]
#ElHamNewTE = [x / y for x,y in zip(ElHamNewTE, iteration_value)]
#StepKmeans = [x / y for x,y in zip(StepKmeans, iteration_value)]
#MARIGOLD = [x / y for x,y in zip(MARIGOLD, iteration_value)]




myfig = plt.figure(figsize=(fig_sizex, fig_sizey))
#plt.subplot(2,1,1)
#plt.plot(x_axis, LlKmeans, color='blue', lw=1, label='LlKmeans')
#plt.plot(x_axis, LlKmeans, lw=1, label='LlKmeans', linestyle=':', marker='v')
plt.plot(x_axis, ElKmeans, lw=1, label='ElKmeans', linestyle=':', marker='s')
plt.plot(x_axis, HamKmeans, lw=1, label='HamKmeans', linestyle=':', marker='h')
#plt.plot(x_axis, ElNewTE, lw=1, label='ElNewTE', linestyle='-.', marker='d')
#plt.plot(x_axis, HamNewTE, lw=1, label='HamNewTE', linestyle='-.', marker='+')
#plt.plot(x_axis, ElHamNewTE, lw=1, label='ElHamNewTE', linestyle='-.', marker='x')
plt.plot(x_axis, StepKmeans, lw=1, label='StepKmeans', linestyle=':', marker='o')
#plt.plot(x_axis, MARIGOLD, lw=1.5, label='MARIGOLD', linestyle='-.', marker='*')
#plt.xscale('log')
plt.xscale('log', base=2)
plt.yscale('log')
plt.ylabel('Runtime (s)')
plt.xlabel('DCT components')
#plt.xlim(1, 7)
plt.title('Missfit Bi5d N:168 K:5')
plt.legend(loc="upper left")
plt.xticks(x_axis)
plt.show()

image_format = 'svg' # e.g .png, .svg, etc.
image_name = 'img_feature numbers (rough).svg'
myfig.savefig(image_name, format=image_format, dpi=600)

##############################################################################################

# %%
#### gr_flake_Full

###Calculation count comparison in percentage
#LlKmeans = [23520, 94080, 376320, 1505280, 4300800, 18923520, 72253440, 330301440, 1541406720]
ElKmeans = [0.0062, 0.022, 0.074, 0.269, 1.271, 6.666]
HamKmeans = [0.024, 0.155, 0.418, 1.422, 6.235, 36.370]
#ElNewTE = [9656, 38428, 154480, 617344, 1835264, 8040448, 31035392, 143392768, 659423232]
#HamNewTE = [6599, 74844, 300384, 1203584, 3438080, 15230976, 58978304, 268828672, 1235025920]
#ElHamNewTE = [9765, 38888, 155744, 644032, 1855744, 8114176, 31281152, 144277504, 662896640]
StepKmeans = [0.026, 0.081, 0.190, 0.361, 1.338, 8.165]
#MARIGOLD = [21406, 68831, 343440, 1122080, 2408640, 8933744, 21958896, 80692080, 357592320]
x_axis = [8*8, 16*16, 32*32, 64*64, 128*128, 256*256]
#x_axis = [1, 4, 16, 64, 256, 1024, 4096, 16384, 65536]
#iteration_value = [28, 28, 28, 28, 20, 22, 21, 24, 28]

#LlKmeans = [x / y for x,y in zip(LlKmeans, iteration_value)]
#ElKmeans = [x / y for x,y in zip(ElKmeans, iteration_value)]
#HamKmeans = [x / y for x,y in zip(HamKmeans, iteration_value)]
#ElNewTE = [x / y for x,y in zip(ElNewTE, iteration_value)]
#HamNewTE = [x / y for x,y in zip(HamNewTE, iteration_value)]
#ElHamNewTE = [x / y for x,y in zip(ElHamNewTE, iteration_value)]
#StepKmeans = [x / y for x,y in zip(StepKmeans, iteration_value)]
#MARIGOLD = [x / y for x,y in zip(MARIGOLD, iteration_value)]




myfig = plt.figure(figsize=(fig_sizex, fig_sizey))
#plt.subplot(2,1,1)
#plt.plot(x_axis, LlKmeans, color='blue', lw=1, label='LlKmeans')
#plt.plot(x_axis, LlKmeans, lw=1, label='LlKmeans', linestyle=':', marker='v')
plt.plot(x_axis, ElKmeans, lw=1, label='ElKmeans', linestyle=':', marker='s')
plt.plot(x_axis, HamKmeans, lw=1, label='HamKmeans', linestyle=':', marker='h')
#plt.plot(x_axis, ElNewTE, lw=1, label='ElNewTE', linestyle='-.', marker='d')
#plt.plot(x_axis, HamNewTE, lw=1, label='HamNewTE', linestyle='-.', marker='+')
#plt.plot(x_axis, ElHamNewTE, lw=1, label='ElHamNewTE', linestyle='-.', marker='x')
plt.plot(x_axis, StepKmeans, lw=1, label='StepKmeans', linestyle=':', marker='o')
#plt.plot(x_axis, MARIGOLD, lw=1.5, label='MARIGOLD', linestyle='-.', marker='*')
#plt.xscale('log')
plt.xscale('log', base=2)
plt.yscale('log')
plt.ylabel('Runtime (s)')
plt.xlabel('DCT components')
#plt.xlim(1, 7)
plt.title('gr_flake_Full N:1911 K:5 Compiler:Clang Optimizer:O2')
plt.legend(loc="upper left")
plt.xticks(x_axis)
plt.show()

image_format = 'svg' # e.g .png, .svg, etc.
image_name = 'img_feature numbers (rough).svg'
myfig.savefig(image_name, format=image_format, dpi=600)

##############################################################################################

# %%
#### gr_flake_Full no optimizer Low N

###Calculation count comparison in percentage
#LlKmeans = [23520, 94080, 376320, 1505280, 4300800, 18923520, 72253440, 330301440, 1541406720]
ElKmeans =  [0.0014, 0.0040, 0.0146, 0.088, 0.38, 2.34]
HamKmeans = [0.0027, 0.0086, 0.03, 0.18, 0.77, 9.73]
#ElNewTE = [9656, 38428, 154480, 617344, 1835264, 8040448, 31035392, 143392768, 659423232]
#HamNewTE = [6599, 74844, 300384, 1203584, 3438080, 15230976, 58978304, 268828672, 1235025920]
#ElHamNewTE = [9765, 38888, 155744, 644032, 1855744, 8114176, 31281152, 144277504, 662896640]
StepKmeans = [0.0028, 0.0052, 0.0142, 0.079, 0.39, 2.16]
#MARIGOLD = [21406, 68831, 343440, 1122080, 2408640, 8933744, 21958896, 80692080, 357592320]
x_axis = [8*8, 16*16, 32*32, 64*64, 128*128, 256*256]
#x_axis = [1, 4, 16, 64, 256, 1024, 4096, 16384, 65536]
#iteration_value = [28, 28, 28, 28, 20, 22, 21, 24, 28]

#LlKmeans = [x / y for x,y in zip(LlKmeans, iteration_value)]
#ElKmeans = [x / y for x,y in zip(ElKmeans, iteration_value)]
#HamKmeans = [x / y for x,y in zip(HamKmeans, iteration_value)]
#ElNewTE = [x / y for x,y in zip(ElNewTE, iteration_value)]
#HamNewTE = [x / y for x,y in zip(HamNewTE, iteration_value)]
#ElHamNewTE = [x / y for x,y in zip(ElHamNewTE, iteration_value)]
#StepKmeans = [x / y for x,y in zip(StepKmeans, iteration_value)]
#MARIGOLD = [x / y for x,y in zip(MARIGOLD, iteration_value)]




myfig = plt.figure(figsize=(fig_sizex, fig_sizey))
#plt.subplot(2,1,1)
#plt.plot(x_axis, LlKmeans, color='blue', lw=1, label='LlKmeans')
#plt.plot(x_axis, LlKmeans, lw=1, label='LlKmeans', linestyle=':', marker='v')
plt.plot(x_axis, ElKmeans, lw=1, label='ElKmeans', linestyle=':', marker='s')
plt.plot(x_axis, HamKmeans, lw=1, label='HamKmeans', linestyle=':', marker='h')
#plt.plot(x_axis, ElNewTE, lw=1, label='ElNewTE', linestyle='-.', marker='d')
#plt.plot(x_axis, HamNewTE, lw=1, label='HamNewTE', linestyle='-.', marker='+')
#plt.plot(x_axis, ElHamNewTE, lw=1, label='ElHamNewTE', linestyle='-.', marker='x')
plt.plot(x_axis, StepKmeans, lw=1, label='StepKmeans', linestyle=':', marker='o')
#plt.plot(x_axis, MARIGOLD, lw=1.5, label='MARIGOLD', linestyle='-.', marker='*')
#plt.xscale('log')
plt.xscale('log', base=2)
plt.yscale('log')
plt.ylabel('Runtime (s)')
plt.xlabel('DCT components')
#plt.xlim(1, 7)
plt.title('gr_flake_Full N:168 K:5')
plt.legend(loc="upper left")
plt.xticks(x_axis)
#plt.show()

image_format = 'svg' # e.g .png, .svg, etc.
image_name = 'img_feature numbers (rough).svg'
myfig.savefig(image_name, format=image_format, dpi=600)


##############################################################################################

# %%
#### gr_flake_Full no optimizer Full N

###Calculation count comparison in percentage
#LlKmeans = [23520, 94080, 376320, 1505280, 4300800, 18923520, 72253440, 330301440, 1541406720]
ElKmeans =  [0.036, 0.21, 0.52, 1.63, 8.74]
HamKmeans = [0.10, 0.68, 1.47, 6.29, 27.63]
#ElNewTE = [9656, 38428, 154480, 617344, 1835264, 8040448, 31035392, 143392768, 659423232]
#HamNewTE = [6599, 74844, 300384, 1203584, 3438080, 15230976, 58978304, 268828672, 1235025920]
#ElHamNewTE = [9765, 38888, 155744, 644032, 1855744, 8114176, 31281152, 144277504, 662896640]
StepKmeans = [0.13, 0.63, 1.23, 2.39, 9.91]
#MARIGOLD = [21406, 68831, 343440, 1122080, 2408640, 8933744, 21958896, 80692080, 357592320]
x_axis = [8*8, 16*16, 32*32, 64*64, 128*128]#, 256*256]
#x_axis = [1, 4, 16, 64, 256, 1024, 4096, 16384, 65536]
#iteration_value = [28, 28, 28, 28, 20, 22, 21, 24, 28]

#LlKmeans = [x / y for x,y in zip(LlKmeans, iteration_value)]
#ElKmeans = [x / y for x,y in zip(ElKmeans, iteration_value)]
#HamKmeans = [x / y for x,y in zip(HamKmeans, iteration_value)]
#ElNewTE = [x / y for x,y in zip(ElNewTE, iteration_value)]
#HamNewTE = [x / y for x,y in zip(HamNewTE, iteration_value)]
#ElHamNewTE = [x / y for x,y in zip(ElHamNewTE, iteration_value)]
#StepKmeans = [x / y for x,y in zip(StepKmeans, iteration_value)]
#MARIGOLD = [x / y for x,y in zip(MARIGOLD, iteration_value)]




myfig = plt.figure(figsize=(fig_sizex, fig_sizey))
#plt.subplot(2,1,1)
#plt.plot(x_axis, LlKmeans, color='blue', lw=1, label='LlKmeans')
#plt.plot(x_axis, LlKmeans, lw=1, label='LlKmeans', linestyle=':', marker='v')
plt.plot(x_axis, ElKmeans, lw=1, label='ElKmeans', linestyle=':', marker='s')
plt.plot(x_axis, HamKmeans, lw=1, label='HamKmeans', linestyle=':', marker='h')
#plt.plot(x_axis, ElNewTE, lw=1, label='ElNewTE', linestyle='-.', marker='d')
#plt.plot(x_axis, HamNewTE, lw=1, label='HamNewTE', linestyle='-.', marker='+')
#plt.plot(x_axis, ElHamNewTE, lw=1, label='ElHamNewTE', linestyle='-.', marker='x')
plt.plot(x_axis, StepKmeans, lw=1, label='StepKmeans', linestyle=':', marker='o')
#plt.plot(x_axis, MARIGOLD, lw=1.5, label='MARIGOLD', linestyle='-.', marker='*')
#plt.xscale('log')
plt.xscale('log', base=2)
plt.yscale('log')
plt.ylabel('Runtime (s)')
plt.xlabel('DCT components')
#plt.xlim(1, 7)
plt.title('gr_flake_Full N:1911 K:5')
plt.legend(loc="upper left")
plt.xticks(x_axis)
plt.show()

image_format = 'svg' # e.g .png, .svg, etc.
image_name = 'img_feature numbers (rough).svg'
myfig.savefig(image_name, format=image_format, dpi=600)

##############################################################################################
